# %%
import pandas as pd 
import numpy as np 
from sklearn.linear_model import LinearRegression

# %%
import pandas as pd
import numpy as np

# Read the CSV file and select specific columns
df = pd.read_csv('50_Startups.csv')[['R&D Spend', 'Administration', 'Marketing Spend', 'Profit']]

# Scale the data by dividing by 10,000 and round to the nearest whole number
df = np.round(df / 10000)

# Set the random seed for reproducibility
np.random.seed(9)

# %%
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend  Profit
# 0       17.0            14.0             47.0    19.0
# 1       16.0            15.0             44.0    19.0
# 2       15.0            10.0             41.0    19.0
# 3       14.0            12.0             38.0    18.0
# 4       14.0             9.0             37.0    17.0

# %%
df = df.iloc[:,0:-1]
df
# Out:
#     R&D Spend  Administration  Marketing Spend
# 0        17.0            14.0             47.0
# 1        16.0            15.0             44.0
# 2        15.0            10.0             41.0
# 3        14.0            12.0             38.0
# 4        14.0             9.0             37.0
# 5        13.0            10.0             36.0
# 6        13.0            15.0             13.0
# 7        13.0            15.0             32.0
# 8        12.0            15.0             31.0
# 9        12.0            11.0             30.0
# 10       10.0            11.0             23.0
# 11       10.0             9.0             25.0
# 12        9.0            13.0             25.0
# 13        9.0            14.0             25.0
# 14       12.0            16.0             26.0
# 15       11.0            12.0             26.0
# 16        8.0            12.0             26.0
# 17        9.0            15.0             28.0
# 18        9.0            11.0             29.0
# ...

# %%
df.shape
# Out:
# (50, 3)

# %%
#  to make some values as NaN
df.iloc[1,0] = np.NaN
df.iloc[3,1] = np.NaN
df.iloc[-1,-1] = np.NaN

# %%
df
# Out:
#     R&D Spend  Administration  Marketing Spend
# 0        17.0            14.0             47.0
# 1         NaN            15.0             44.0
# 2        15.0            10.0             41.0
# 3        14.0             NaN             38.0
# 4        14.0             9.0             37.0
# 5        13.0            10.0             36.0
# 6        13.0            15.0             13.0
# 7        13.0            15.0             32.0
# 8        12.0            15.0             31.0
# 9        12.0            11.0             30.0
# 10       10.0            11.0             23.0
# 11       10.0             9.0             25.0
# 12        9.0            13.0             25.0
# 13        9.0            14.0             25.0
# 14       12.0            16.0             26.0
# 15       11.0            12.0             26.0
# 16        8.0            12.0             26.0
# 17        9.0            15.0             28.0
# 18        9.0            11.0             29.0
# ...
