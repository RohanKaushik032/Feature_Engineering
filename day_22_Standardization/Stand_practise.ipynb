# %%
import numpy as np 
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('wine_data.csv',header = None , usecols = [0,1,2,3])

# %%
df.sample(2)
# Out:
#      0      1     2     3
# 32   1  13.68  1.83  2.36
# 144  3  12.25  3.88  2.20

# %%
df.columns = ['Class label', 'Alcohol', 'Malic acid','Alcohol_%']
df.sample()
# Out:
#     Class label  Alcohol  Malic acid  Alcohol_%
# 66            2    13.11        1.01        1.7

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test =train_test_split(df.drop('Alcohol_%',axis = 1),
                                                       df['Alcohol_%'],
                                                       test_size =0.3,
                                               random_state = 0)

# %%
x_train.sample()
# Out:
#     Class label  Alcohol  Malic acid
# 13            1    14.75        1.73

# %%
y_train.sample()
# Out:
# 97    1.98
# Name: Alcohol_%, dtype: float64

# %%
# Standard Scaler
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
sc.fit(x_train)
# Out:
# StandardScaler()

# %%
x_train_scaled = sc.transform(x_train)
x_test_scaled = sc.transform(x_test)

# %%
x_train_scaled
# Out:
# array([[-1.23563443,  0.91083058, -0.46259897],
#        [ 0.05191741, -0.95609928, -0.96608672],
#        [ 1.33946926,  0.35952243,  1.67501572],
#        [ 1.33946926,  0.22169539,  1.0478643 ],
#        [ 0.05191741,  1.09877654, -0.77175811],
#        [ 1.33946926, -0.16672625,  0.78287075],
#        [ 1.33946926,  1.07371707,  1.53368582],
#        [-1.23563443,  0.39711162, -0.58626262],
#        [ 0.05191741,  0.08386836,  1.30402474],
#        [ 1.33946926, -0.59273709, -1.01025231],
#        [ 0.05191741, -0.86839117, -0.8600893 ],
#        [ 0.05191741, -0.2669641 ,  0.92420064],
#        [ 1.33946926, -0.02889922,  0.94186688],
#        [ 0.05191741,  0.86071165, -1.0014192 ],
#        [-1.23563443,  0.22169539, -0.02094304],
#        [ 0.05191741, -0.76815332, -1.27524587],
#        [ 0.05191741, -0.64285602, -0.762925  ],
#        [ 0.05191741, -1.46981823, -0.23293788],
#        [-1.23563443,  0.32193324,  1.41002216],
#        [-1.23563443,  1.39949007, -0.19760541],
# ...

# %%
x_train_scaled = pd.DataFrame(x_train_scaled,columns = x_train.columns)

# %%
x_test_scaled = pd.DataFrame(x_test_scaled,columns = x_test.columns)

# %%
x_test_scaled
# Out:
#     Class label   Alcohol  Malic acid
# 0     -1.235634  0.948420   -0.630428
# 1      1.339469 -0.241905    0.252884
# 2      0.051917 -0.768153   -1.107417
# 3     -1.235634  0.722885   -0.577430
# 4      0.051917  0.083868    3.017650
# 5      0.051917 -1.783061   -0.294770
# 6     -1.235634  1.349371   -0.206439
# 7      1.339469 -0.780683    1.277525
# 8      0.051917 -0.918510   -0.577430
# 9      0.051917 -1.131516   -0.489098
# 10     1.339469  0.472290    0.155719
# 11     1.339469  1.123836    2.346333
# 12    -1.235634  1.524787   -0.550930
# 13     0.051917 -0.768153   -1.160415
# 14     1.339469  0.747944    0.173386
# 15     0.051917 -1.231753   -1.292912
# 16    -1.235634  0.973479   -0.754092
# 17    -1.235634  1.512258   -0.701093
# 18     0.051917 -0.429851   -0.904255
# 19    -1.235634  1.061187   -0.648094
# 20     0.051917  0.159047   -1.213414
# 21    -1.235634  0.083868   -0.648094
# 22    -1.235634  0.321933    0.182219
# 23     0.051917 -0.592737   -0.577430
# ...

# %%
fig, (ax1,ax2)= plt.subplots(ncols = 2, figsize = (10,5))

sns.kdeplot(x_train['Malic acid'],ax= ax1)
sns.kdeplot(x_train_scaled['Malic acid'],ax= ax2)

plt.show()

# %%
np.round(x_train.describe(),1)
# Out:
#        Class label  Alcohol  Malic acid
# count        124.0    124.0       124.0
# mean           2.0     13.0         2.4
# std            0.8      0.8         1.1
# min            1.0     11.0         0.9
# 25%            1.0     12.4         1.6
# 50%            2.0     13.0         1.9
# 75%            3.0     13.6         3.2
# max            3.0     14.8         5.6

# %%
np.round(x_train_scaled.describe(),1)
# Out:
#        Class label  Alcohol  Malic acid
# count        124.0    124.0       124.0
# mean          -0.0     -0.0        -0.0
# std            1.0      1.0         1.0
# min           -1.2     -2.4        -1.3
# 25%           -1.2     -0.8        -0.7
# 50%            0.1      0.1        -0.4
# 75%            1.3      0.8         0.8
# max            1.3      2.2         2.9

# %%
from sklearn.linear_model import LinearRegression 
lr = LinearRegression()

# %%
lr.fit(x_train_scaled,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test_scaled)

# %%
y_pred
# Out:
# array([2.38787604, 2.36040072, 2.26248393, 2.37741578, 2.52022368,
#        2.24438046, 2.43261724, 2.38072075, 2.2804672 , 2.27251925,
#        2.39709012, 2.54555622, 2.42545212, 2.25980999, 2.41403434,
#        2.22612707, 2.3830962 , 2.41714628, 2.29243533, 2.39355182,
#        2.3111322 , 2.33663697, 2.39239257, 2.29943882, 2.25822825,
#        2.33136447, 2.28468827, 2.26855222, 2.28705038, 2.43664972,
#        2.36679389, 2.42423754, 2.37967774, 2.52779152, 2.46607393,
#        2.34198485, 2.45236545, 2.30365988, 2.24608458, 2.46017248,
#        2.37660297, 2.3795702 , 2.33240815, 2.28862531, 2.17505427,
#        2.44430817, 2.33717805, 2.23078452, 2.37492258, 2.43987941,
#        2.38122883, 2.45247857, 2.37652447, 2.42938074])

# %%
from sklearn.metrics import accuracy_score

# %%
y_test
# Out:
# 54     2.25
# 151    2.48
# 63     2.16
# 55     2.46
# 123    2.13
# 121    3.23
# 7      2.61
# 160    2.38
# 106    2.12
# 90     2.32
# 141    2.35
# 146    2.23
# 5      2.45
# 98     2.10
# 168    2.69
# 80     2.00
# 33     2.70
# 18     2.48
# 61     2.02
# 51     2.60
# 66     1.70
# 37     2.55
# 4      2.87
# 104    1.98
# 60     2.28
# 111    2.17
# 126    2.29
# 86     2.31
# 112    2.92
# 164    2.30
# 26     2.62
# 56     2.30
# 129    2.38
# 45     2.44
# 8      2.17
# 44     2.10
# 161    2.54
# 92     2.26
# 94     2.28
# 174    2.48
# 24     2.61
# 30     2.70
# 93     2.22
# 101    1.90
# 113    2.50
# 19     2.56
# 135    2.20
# 74     2.30
# 144    2.20
# 16     2.72
# 131    2.40
# 138    2.19
# 40     2.31
# 158    2.70
# Name: Alcohol_%, dtype: float64

# %%
y_pred
# Out:
# array([2.38787604, 2.36040072, 2.26248393, 2.37741578, 2.52022368,
#        2.24438046, 2.43261724, 2.38072075, 2.2804672 , 2.27251925,
#        2.39709012, 2.54555622, 2.42545212, 2.25980999, 2.41403434,
#        2.22612707, 2.3830962 , 2.41714628, 2.29243533, 2.39355182,
#        2.3111322 , 2.33663697, 2.39239257, 2.29943882, 2.25822825,
#        2.33136447, 2.28468827, 2.26855222, 2.28705038, 2.43664972,
#        2.36679389, 2.42423754, 2.37967774, 2.52779152, 2.46607393,
#        2.34198485, 2.45236545, 2.30365988, 2.24608458, 2.46017248,
#        2.37660297, 2.3795702 , 2.33240815, 2.28862531, 2.17505427,
#        2.44430817, 2.33717805, 2.23078452, 2.37492258, 2.43987941,
#        2.38122883, 2.45247857, 2.37652447, 2.42938074])

# %%
from sklearn.metrics import r2_score
print("R2_score of model ",r2_score(y_test,y_pred))
# Out:
# R2_score of model  0.012994176182826722
